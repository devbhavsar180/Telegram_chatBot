# %%
import telegram.ext

def start(update, context):
    user_name = update.message.from_user.first_name
    update.message.reply_text(f"Hello, {user_name}! Welcome to  channel.")

def help(update, context):
    update.message.reply_text("""
    The following commands are available:
    
    /start -> Welcome to the channel
    /help -> This message
    /content -> I create this code for my individual project
    /Python  -> Our sir Keval Patel teaches us Python
    /SQL -> SQL is great
    /Java -> The first video from Java Playlist
    /Skillup -> Python, FSD , daa 
    /contact -> My contact number is 9727481889
    /collage -> DAA SUB IS USEFUL 
    
    """)

def content(update, context):
    update.message.reply_text("We have various playlists and articles available!")

def Python(update, context):
    update.message.reply_text("Our sir Keval Patel teaches us Python")

def SQL(update, context):
    update.message.reply_text("SQL is great")

def Java(update, context):
    update.message.reply_text("The first video from Java Playlist")

def Skillup(update, context):
    update.message.reply_text("Python, FSD , DAA")

def contact(update, context):
    update.message.reply_text("My contact number is 9727481889")
    
def collage(update, context):
    update.message.reply_text("this is collage functions")

def handle_message(update, context):
    update.message.reply_text(f"You said {update.message.text}, use the commands using /")
    


Token = "6846323171:AAE4Pjobw5It6z5mAX4ApH92kRWvpSyUagI"
updater = telegram.ext.Updater(Token, use_context=True)
disp = updater.dispatcher

disp.add_handler(telegram.ext.CommandHandler('start', start))
disp.add_handler(telegram.ext.CommandHandler('help', help))
disp.add_handler(telegram.ext.CommandHandler('content', content))
disp.add_handler(telegram.ext.CommandHandler('Python', Python))
disp.add_handler(telegram.ext.CommandHandler('SQL', SQL))
disp.add_handler(telegram.ext.CommandHandler('Java', Java))
disp.add_handler(telegram.ext.CommandHandler('Skillup', Skillup))
disp.add_handler(telegram.ext.CommandHandler('contact', contact))
disp.add_handler(telegram.ext.CommandHandler('collage',collage))
disp.add_handler(telegram.ext.MessageHandler(telegram.ext.Filters.text, handle_message))

updater.start_polling()
updater.idle()
# Out:
# Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\Dev Bhavsar\anaconda3\lib\site-packages\telegram\ext\updater.py", line 646, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\Dev Bhavsar\anaconda3\lib\site-packages\telegram\ext\updater.py", line 597, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "C:\Users\Dev Bhavsar\anaconda3\lib\site-packages\telegram\ext\extbot.py", line 222, in get_updates
#     updates = super().get_updates(
#   File "C:\Users\Dev Bhavsar\anaconda3\lib\site-packages\telegram\bot.py", line 130, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\Dev Bhavsar\anaconda3\lib\site-packages\telegram\bot.py", line 2861, in get_updates
#     self._post(
# ...
